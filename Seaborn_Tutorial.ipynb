# %% [markdown]
# # Seaborn Tutorial – Data Visualization
#
#
# **Goals**
#
# * Introduce Seaborn’s high‑level API for statistical graphics.
# * Demonstrate core plot types for exploratory data analysis (EDA).
# * Show how Seaborn integrates with pandas DataFrames.
# * Practice styling themes and palettes for publication‑quality figures.

# %% [markdown]
# Seaborn is a library for making statistical graphics in Python. It is a data visualization library that is built on top of Matplotlib and integrates closely with pandas data structures.

# %% [markdown]
# Matplotlib predated Pandas by more than a decade, and thus is not designed for use with Pandas DataFrames. In order to visualize data from a Pandas DataFrame, you must extract each Series and often concatenate them together into the right format. It would be nicer to have a plotting library that can intelligently use the DataFrame labels in a plot.

# %% [markdown]
# Seaborn provides an API ( Application Programming Interface)on top of Matplotlib that offers sane choices for plot style and color defaults, defines simple high-level functions for common statistical plot types, and integrates with the functionality provided by Pandas DataFrames.
# Provides a high-level interface.  You can make complex charts with a single line of code!
# Makes it easy to create attractive charts out of the box!

# %% [markdown]
# **What we’ll do:** This cell demonstrates a Seaborn feature.

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
#%matplotlib inline

# %%
tips = sb.load_dataset('tips')
flights=sb.load_dataset('flights')
titanic=sb.load_dataset('titanic')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %% [markdown]
# # Line and Scatter Plots

# %% [markdown]
# ## Axis-level - scatterplot, lineplot

# %% [markdown]
# Single axes-level-They plot data onto a single matplotlib.pyplot.Axes object|

# %% [markdown]
# Scatter plot to examine relationship between two numeric variables.

# %%
plt.figure(figsize=(8,6))
sb.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Line plot to show trend across an ordered variable.

# %%
plt.figure(figsize=(8,6))
sb.lineplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# Inspect the dataset structure and summary statistics.

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
plt.figure(figsize=(8,6))
sb.scatterplot(data=flights, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# יצירת נתונים
np.random.seed(42)

# נקודה 1: הרבה נקודות, פיזור גדול ב-y
x1 = np.ones(500)
y1 = np.random.normal(loc=0, scale=10, size=500)  # פיזור גדול מאוד

# נקודה 2: מעט נקודות, פיזור קטן ב-y
x2 = np.ones(2) * 2
y2 = np.random.normal(loc=0, scale=10, size=2)  # פיזור קטן יותר

# איחוד הנתונים
x = np.concatenate([x1, x2])
y = np.concatenate([y1, y2])

df = pd.DataFrame({'x': x, 'y': y})

# ציור
plt.figure(figsize=(8,5))
sb.scatterplot(data=df, x='x', y='y')
plt.xticks([1, 2])
plt.title('Scatterplot: פיזור שונה בכמות ובגודל')
plt.show()

# %%
sb.lineplot(data=df, x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
plt.figure(figsize=(8,6))
sb.lineplot(data=flights, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
plt.figure(figsize=(8,6))
sb.lineplot(data=flights, x="month", y="passengers")
# Out:
# <Axes: xlabel='month', ylabel='passengers'>

# %% [markdown]
# Configure Seaborn’s global style or color palette.

# %%
# sb.set_theme()
sb.set_theme()

# %%
plt.figure(figsize=(8,6))
sb.lineplot(data=flights, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
plt.figure(figsize=(8,6))
sb.lineplot(data=flights, x="year", y="passengers", estimator='sum')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# **Exercise:** Create the lineplot above with pandas and matplotlib (Do not use seaborn)

# %%
# Your code goes here

# %%
sb.scatterplot(data=tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize=(8,6))
sb.scatterplot(data=tips, x="total_bill", y="tip",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize=(8,6))
sb.scatterplot(data=tips, x="total_bill", y="tip",hue="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize=(8,6))
sb.scatterplot(data=tips, x="total_bill", y="tip",hue="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize=(12,8))
sb.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize=(8,6))
sb.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Figure-level with relplot (relational plot)

# %% [markdown]
# Figure-level interface for drawing relational plots onto a FacetGrid.
# This function provides access to several different axes-level functions that show the relationship between two variables with semantic mappings of subsets. The kind parameter selects the underlying axes-level function to use:
# #We can provide:kind, col , row, aspect ,height

# %%
sb.relplot(x='total_bill', y='tip', data=tips)

# %%
sb.relplot(x='total_bill', y='tip', data=tips, kind="scatter", col="smoker")

# %%
sb.relplot(x='total_bill', y='tip', data=tips,kind="scatter",col="smoker",hue='sex')

# %%
sb.relplot(x='total_bill', y='tip', data=tips, kind="line",col="smoker")

# %%
sb.relplot(x='total_bill', y='tip', data=tips,col="day")

# %%
sb.relplot(data=tips, x="total_bill", y="tip", kind="scatter", hue="smoker", col="sex")

# %%
sb.relplot(data=tips, x="total_bill", y="tip", kind="scatter", hue="smoker", col="sex", row="time")

# %%
# sb.relplot(data=tips
sb.relplot(data=tips,
                x="total_bill",
                y="tip", kind="scatter",
                hue="smoker",
                col="sex",
                row="time",
                height=4,
                aspect=2)

# %% [markdown]
# # Histograms, KDEs, Heatmap

# %% [markdown]
# ## Axis Level - histplot, kdeplot

# %%
sb.histplot(data=tips, x="tip")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sb.histplot(data=tips, x="tip",binwidth=0.1)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sb.histplot(data=tips, x="tip",hue="smoker")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sb.histplot(data=tips, x="tip",hue="smoker",multiple="stack")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sb.histplot(data=tips, x="tip",hue="time", multiple="stack", element="step")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sb.histplot(data=tips, x="tip",hue="day",multiple="stack",element="step")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sb.histplot(data=tips, x="tip",element="poly",hue='smoker')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sb.histplot(data=tips, x="tip",kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sb.histplot(data=tips, x="tip",hue="day",multiple="stack",element="step",kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### Heat Map (3D histograms)

# %%
sb.histplot(data=tips, x="tip",y="total_bill")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sb.histplot(data=tips, x="tip",y="total_bill",hue="day")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sb.histplot(data=tips, x="day",y="tip")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ### KDE Plots

# %%
sb.kdeplot(data=tips, x="tip")
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sb.kdeplot(data=tips, x="tip",hue="day")
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sb.kdeplot(data=tips, x="tip",hue="day",multiple="stack")
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
iris = sb.load_dataset("iris")
sb.kdeplot(data=iris)
# Out:
# <Axes: ylabel='Density'>

# %%
sb.kdeplot(data=tips, x="total_bill", bw_adjust=0.2) # play with bw_adjust
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## Figure Level with Distplot

# %% [markdown]
# displot — это высокоуровневая функция для построения гистограмм, графиков плотности (KDE) и/или ECDF-графиков, обычно в комбинации.
#
# ✅ Основные возможности:
# Создаёт гистограмму (по умолчанию)
#
# Можно добавить линии плотности (kde=True)
#
# Поддерживает фасетирование (разбиение по категориям)
#
# Поддерживает DataFrame напрямую, включая группировку и цветовую кодировку

# %% [markdown]
# --------------------------------------------------------------------------
#
# seaborn.kdeplot()
# kdeplot — это низкоуровневая функция, которая рисует только KDE-график (Kernel Density Estimate) — сглаженное представление распределения данных.
#
# ✅ Основные возможности:
# Только график плотности
#
# Больше контроля над параметрами сглаживания, цветами, стилями линий и т.д.
#
# Можно строить 2D-графики плотности

# %% [markdown]
# -----------------------------------------------------------------------
# 📌 Когда использовать:
# displot — когда нужно быстро визуализировать гистограмму, KDE или разбить графики по категориям.
#
# kdeplot — когда нужно точно настроить линию KDE или построить 2D KDE (по двум переменным).

# %%
sb.displot(data=tips, x="tip",hue="day")

# %%
sb.displot(data=tips, x="tip",hue='sex',kind="kde",col="day")

# %%
geyser = sb.load_dataset("geyser")
sb.kdeplot(data=geyser, x="waiting", y="duration") # Axis level
# Out:
# <Axes: xlabel='waiting', ylabel='duration'>

# %%
sb.kdeplot(data=geyser, x="waiting", y="duration", hue="kind") # axis level
# Out:
# <Axes: xlabel='waiting', ylabel='duration'>

# %%
sb.displot(data=tips, x="tip",y="total_bill",kind="kde")
sb.rugplot(data=tips, x="tip",y="total_bill")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# # Categorial plots

# %% [markdown]
# ## Axis-level - explore yourself

# %% [markdown]
# ## Figure-level with Caplot

# %%
sb.catplot(data=tips, x="day", kind='count')

# %%
sb.catplot(data=tips, x="day", kind='count', hue='sex')

# %%
sb.catplot(data=tips, x="day", y="tip", kind='bar')

# %%
sb.catplot(data=tips, x="day", y="tip")

# %%
sb.catplot(data=tips,x="day",y="tip",kind='strip')

# %%
sb.catplot(data=tips, x="day", y="tip", kind='swarm', aspect=2, estimator='sum')

# %%
sb.catplot(data=tips, x="day", y="tip", kind='swarm', aspect=2)

# %% [markdown]
# **What we’ll do:** Categorical plot (wrapper for several types) exploring relationship between categorical and numeric data.

# %%
sb.catplot(data=tips, x="day", y="tip", kind='swarm', aspect=2, hue="sex")

# %%
sb.catplot(data=tips, x="day", y="tip", kind='swarm', aspect=1.5, col="sex")

# %%
sb.catplot(data=tips, x="day", y="tip", kind='swarm', aspect=1.5, row="sex")

# %%
# categorial plot in axis-level 

plt.figure(figsize=(12,5))
sb.swarmplot(data=titanic, x="pclass", y="age")
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
# categorial plot in axis-level 

sb.swarmplot(data=titanic, x="pclass", y="age", hue="sex")
# Out:
# <Axes: xlabel='pclass', ylabel='age'>
# c:\Users\evgen\miniconda3\envs\evgenie_python_env\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sb.catplot(data=titanic, x="pclass", y="age", kind='swarm', col="sex", aspect=2)

# %% [markdown]
# Boxplot (или ящик с усами) — это график, который показывает:
#
# Медиану (центральное значение)
#
# Квартиль 1 (Q1) — 25-й перцентиль
#
# Квартиль 3 (Q3) — 75-й перцентиль
#
# "Усы" — диапазон значений без выбросов
#
# Выбросы (outliers) — точки, сильно отличающиеся от основной массы данных

# %% [markdown]
# |----|=====|----|               ◦    ◦
# min  Q1   med  Q3              выбросы
# Медиана — жирная линия внутри коробки
#
# Коробка = от Q1 до Q3 (это называется межквартильный размах (IQR))
#
# "Усы" — по умолчанию доходят до Q1 - 1.5 * IQR и Q3 + 1.5 * IQR
#
# Точки вне усов — считаются выбросами

# %% [markdown]
# 📌 Когда использовать boxplot?
# Boxplot отлично подходит для:
#
# Сравнения распределений между группами
#
# Поиска выбросов
#
# Быстрой оценки симметрии распределения

# %%
sb.catplot(data=tips,x="day",y="tip",kind='box',aspect=2)

# %%
sb.catplot(data=tips,x="day",y="tip",kind='box',aspect=2, hue="sex")

# %%
sb.catplot(data=tips,x="tip",y="day",kind='box',aspect=2)

# %%
sb.catplot(data=tips,x="day",y="tip",kind='box',aspect=2, hue='sex')

# %%
# boxplot in axis-level 


plt.figure(figsize=(12,9))
sb.boxplot(data=tips,x="day",y="tip")
sb.swarmplot(data=tips,x="day",y="tip",color="0")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sb.catplot(data=tips, x="day", y="tip", kind='violin', aspect=2)

# %%
plt.figure(figsize=(12,6))
sb.violinplot(data=tips, x="day", y="tip")
sb.boxplot(data=tips, x="day", y="tip")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sb.catplot(data=tips,x="day",y="tip", kind='violin', aspect=2,hue="sex")

# %%
sb.catplot(data=tips,x="day",y="tip",kind='violin',aspect=2,col="sex")

# %% [markdown]
# # Heatmap

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.groupby(['year', 'month'])['passengers'].sum().unstack()
# Out:
# C:\Users\evgen\AppData\Local\Temp\ipykernel_3572\2775457186.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   flights.groupby(['year', 'month'])['passengers'].sum().unstack()
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# ...

# %%
sb.heatmap(flights.groupby(['year', 'month'])['passengers'].sum().unstack())
# Out:
# /var/folders/lz/8wt3gqy5069cb1m83rr7d13m0000gn/T/ipykernel_34361/3888655995.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sb.heatmap(flights.groupby(['year', 'month'])['passengers'].sum().unstack())
# <Axes: xlabel='month', ylabel='year'>
